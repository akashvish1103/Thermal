# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv(r"C:\Users\Akash Vishwakarma\Desktop\Thermal_Analysis\basics_mp\breathing_signal_20260320_124243.csv")
df

df = df['Intensity']

# %%
df
# Out:
# 0       74.789216
# 1       75.453147
# 2       76.420363
# 3       75.691398
# 4       74.544951
#           ...
# 2446    91.182097
# 2447    91.179795
# 2448    91.333504
# 2449    91.784143
# 2450    91.610486
# Name: Intensity, Length: 2451, dtype: float64

# %%
arr = np.array(df)

# %%
arr
# Out:
# array([74.78921569, 75.45314685, 76.4203629 , ..., 91.33350384,
#        91.78414322, 91.61048593])

# %%
print(len(arr))
print(arr.ndim)
print(arr.shape)
# Out:
# 2451
# 1
# (2451,)

# %%
plt.plot(arr)
